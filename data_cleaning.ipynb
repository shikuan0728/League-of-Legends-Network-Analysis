# %%
import pandas as pd
import networkx as nx

# %%
# read matachinfo2
df = pd.read_csv("C:/Users/alienware/Desktop/658project/matchinfo_2.csv")
df.head()
# Out:
#    bResult  rResult blueTopChamp blueJungleChamp blueMiddleChamp blueADCChamp  \
# 0        1        0       Irelia          RekSai            Ahri         Jinx
# 1        0        1         Gnar          Rengar            Ahri      Caitlyn
# 2        1        0     Renekton          Rengar            Fizz        Sivir
# 3        0        1       Irelia        JarvanIV         Leblanc        Sivir
# 4        1        0         Gnar        JarvanIV       Lissandra     Tristana
#
#   blueSupportChamp redTopChamp redJungleChamp redMiddleChamp redADCChamp  \
# 0            Janna        Gnar          Elise           Fizz       Sivir
# 1            Leona      Irelia       JarvanIV           Azir       Corki
# 2            Annie        Sion         LeeSin           Azir       Corki
# 3           Thresh        Gnar           Nunu           Lulu      KogMaw
# 4            Janna        Sion         RekSai           Lulu       Corki
#
#   redSupportChamp  Year
# 0          Thresh  2015
# ...

# %%
# checking columns
df.columns
# Out:
# Index(['bResult', 'rResult', 'blueTopChamp', 'blueJungleChamp',
#        'blueMiddleChamp', 'blueADCChamp', 'blueSupportChamp', 'redTopChamp',
#        'redJungleChamp', 'redMiddleChamp', 'redADCChamp', 'redSupportChamp',
#        'Year'],
#       dtype='object')

# %%
# getting 2017
df_year = df.set_index('Year')
df_year_1 = df_year.loc[2017]
df_year_1.head()
# Out:
#       bResult  rResult blueTopChamp blueJungleChamp blueMiddleChamp  \
# Year
# 2017        0        1       Maokai          RekSai          Syndra
# 2017        1        0     Nautilus          LeeSin          Syndra
# 2017        0        1     Nautilus          RekSai         Leblanc
# 2017        1        0       Maokai          Khazix         Orianna
# 2017        0        1     Nautilus          LeeSin           Corki
#
#      blueADCChamp blueSupportChamp redTopChamp redJungleChamp redMiddleChamp  \
# Year
# 2017      Kalista             Zyra        Shen         Khazix           Fizz
# 2017        Varus            Taric     Trundle         RekSai       Katarina
# 2017         Jhin        TahmKench      Maokai         Rengar      Lissandra
# 2017        Varus            Karma      Singed         RekSai         Anivia
# 2017        Varus         Malzahar      Maokai         Khazix     Cassiopeia
#
#      redADCChamp redSupportChamp
# Year
# 2017        Ashe     MissFortune
# ...

# %%
# getting champions choice for blue team win
df_bResult = df_year_1.set_index('bResult')
df_b_win = df_bResult.loc[1]
df_b_win_team = df_b_win[['blueTopChamp','blueJungleChamp','blueMiddleChamp','blueADCChamp','blueSupportChamp']]
df_b_win_team.head()
# Out:
#         blueTopChamp blueJungleChamp blueMiddleChamp blueADCChamp  \
# bResult
# 1           Nautilus          LeeSin          Syndra        Varus
# 1             Maokai          Khazix         Orianna        Varus
# 1           Nautilus          Khazix         Orianna       Twitch
# 1           Nautilus          Graves           Corki         Ashe
# 1             Maokai          Graves     TwistedFate        Varus
#
#         blueSupportChamp
# bResult
# 1                  Taric
# 1                  Karma
# 1                  Karma
# 1                   Zyra
# 1               Malzahar

# %%
df_b_win_team.to_csv("df_b_win_team.csv")

# %%
# getting champions choice for red team win
df_rResult = df_year_1.set_index('rResult')
df_r_win = df_rResult.loc[1]
df_r_win_team = df_r_win[['redTopChamp','redJungleChamp','redMiddleChamp','redADCChamp','redSupportChamp']]
df_r_win_team.head()
# Out:
#         redTopChamp redJungleChamp redMiddleChamp redADCChamp redSupportChamp
# rResult
# 1              Shen         Khazix           Fizz        Ashe     MissFortune
# 1            Maokai         Rengar      Lissandra       Varus            Nami
# 1            Maokai         Khazix     Cassiopeia        Ashe            Lulu
# 1            Maokai         LeeSin          Corki       Varus           Karma
# 1            Maokai         Khazix           Fizz       Varus         Morgana

# %%
df_r_win_team.to_csv("df_r_win_team.csv")

# %%
# reading 2017 all win teams champions choose
df1 = pd.read_csv("C:/Users/alienware/Desktop/658project/matchinfo_winteam.csv")
df1
# Out:
#             TOP       JG          MID      ADC          SUP
# 0      Nautilus   LeeSin       Syndra    Varus        Taric
# 1        Maokai   Khazix      Orianna    Varus        Karma
# 2      Nautilus   Khazix      Orianna   Twitch        Karma
# 3      Nautilus   Graves        Corki     Ashe         Zyra
# 4        Maokai   Graves  TwistedFate    Varus     Malzahar
# 5         Fiora   RekSai         Ryze    Varus      Morgana
# 6        Maokai   Rengar   Cassiopeia   Ezreal        Karma
# 7        Maokai    Elise        Corki     Ashe  MissFortune
# 8         Fiora   RekSai         Ryze     Ashe       Thresh
# 9      Nautilus   Khazix   Cassiopeia     Ashe        Karma
# 10       Maokai   Khazix       Syndra  Caitlyn      Morgana
# 11       Maokai   LeeSin   Cassiopeia     Ashe       Thresh
# 12     Nautilus     Olaf     Katarina     Ashe  MissFortune
# 13        Fiora   RekSai         Ekko     Ashe  MissFortune
# 14       Maokai   Khazix        Corki  Caitlyn     Malzahar
# ...

# %%
# getting all middle and jungle champions cross table
df2 = pd.crosstab(df1.MID, df1.JG)
df2
# Out:
# JG            Bard  Camille  Chogath  Draven  Ekko  Elise  Evelynn  Ezreal  \
# MID
# Ahri             0        1        0       0     0     17        0       0
# Akali            0        0        0       0     0      0        0       0
# Anivia           0        0        0       0     0      1        0       0
# AurelionSol      0        0        0       0     0      4        0       0
# Azir             0        0        0       0     0      3        0       0
# Camille          0        0        0       0     0      0        0       0
# Cassiopeia       0        0        4       0     0     30        0       0
# Corki            0        0        5       0     0     30        2       0
# Ekko             0        0        0       0     0     15        0       0
# Fiora            0        0        0       0     0      0        0       0
# Fizz             0        0        0       0     0      3        0       0
# ...

# %%
df2.to_csv("matrix_mj_52_36.csv")

# %%
# adjacency matrix！
df3 = pd.crosstab(df1.MID, df1.JG)
idx = df2.columns.union(df2.index)
df3 = df2.reindex(index = idx, columns=idx, fill_value=0)
df3
# Out:
#               Ahri  Akali  Anivia  AurelionSol  Azir  Bard  Camille  \
# Ahri             0      0       0            0     0     0        1
# Akali            0      0       0            0     0     0        0
# Anivia           0      0       0            0     0     0        0
# AurelionSol      0      0       0            0     0     0        0
# Azir             0      0       0            0     0     0        0
# Bard             0      0       0            0     0     0        0
# Camille          0      0       0            0     0     0        0
# Cassiopeia       0      0       0            0     0     0        0
# Chogath          0      0       0            0     0     0        0
# Corki            0      0       0            0     0     0        0
# Draven           0      0       0            0     0     0        0
# Ekko             0      0       0            0     0     0        0
# Elise            0      0       0            0     0     0        0
# ...

# %%
df3.to_csv("matrix_mj_81_81.csv")

# %%
# getting all ADC and support champions cross table
df4 = pd.crosstab(df1.ADC, df1.SUP)
df4
# Out:
# SUP           Alistar  Ashe  Bard  Blitzcrank  Brand  Braum  Camille  Elise  \
# ADC
# Alistar             0     0     0           0      0      0        0      0
# Ashe                6     0    11           3      4     29        2      0
# Caitlyn             6     0    14          13      1     55        0      0
# Corki               0     0     0           0      0      1        0      0
# Draven              1     1     0           1      1      0        0      0
# Ezreal              0     0     1           0      0      5        1      0
# Heimerdinger        0     0     0           0      0      0        0      0
# Irelia              0     0     0           0      0      0        0      0
# Jhin                6     0    11           6      3     28        1      0
# Jinx                0     0     0           0      0      4        0      0
# Kalista            23     0     3          18      1     46        0      0
# ...

# %%
df4.to_csv("matrix_as_25_41.csv")

# %%
# adjacency matrix！
df5 = pd.crosstab(df1.ADC, df1.SUP)
idx = df4.columns.union(df4.index)
df5 = df4.reindex(index = idx, columns=idx, fill_value=0)
df5
# Out:
#               Alistar  Ashe  Bard  Blitzcrank  Brand  Braum  Caitlyn  Camille  \
# Alistar             0     0     0           0      0      0        0        0
# Ashe                6     0    11           3      4     29        0        2
# Bard                0     0     0           0      0      0        0        0
# Blitzcrank          0     0     0           0      0      0        0        0
# Brand               0     0     0           0      0      0        0        0
# Braum               0     0     0           0      0      0        0        0
# Caitlyn             6     0    14          13      1     55        0        0
# Camille             0     0     0           0      0      0        0        0
# Corki               0     0     0           0      0      1        0        0
# Draven              1     1     0           1      1      0        0        0
# Elise               0     0     0           0      0      0        0        0
# ...

# %%
df5.to_csv("matrix_as_60_60.csv")
