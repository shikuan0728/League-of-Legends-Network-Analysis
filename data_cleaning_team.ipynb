# %%
import pandas as pd
import numpy as np
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read matachinfo
df = pd.read_csv("C:/Users/alienware/Desktop/658project/matchinfo.csv")
df.head()
# Out:
#   League  Year  Season    Type blueTeamTag  bResult  rResult redTeamTag  \
# 0  NALCS  2015  Spring  Season         TSM        1        0         C9
# 1  NALCS  2015  Spring  Season         CST        0        1        DIG
# 2  NALCS  2015  Spring  Season         WFX        1        0         GV
# 3  NALCS  2015  Spring  Season         TIP        0        1         TL
# 4  NALCS  2015  Spring  Season         CLG        1        0         T8
#
#    gamelength  blueTop                        ...                          \
# 0          40    Dyrus                        ...
# 1          38     Cris                        ...
# 2          40  Flaresz                        ...
# 3          41     Rhux                        ...
# 4          35    Benny                        ...
#
#   redTopChamp     redJungle redJungleChamp redMiddle redMiddleChamp  \
# 0        Gnar        Meteos          Elise       Hai           Fizz
# ...

# %%
# getting 2017
df_year = df.set_index('Year')
df_year_1 = df_year.loc[2017]
df_year_1.head()
# Out:
#      League  Season    Type blueTeamTag  bResult  rResult redTeamTag  \
# Year
# 2017  NALCS  Spring  Season         TSM        0        1         C9
# 2017  NALCS  Spring  Season          C9        1        0        TSM
# 2017  NALCS  Spring  Season         FOX        0        1         P1
# 2017  NALCS  Spring  Season          P1        1        0        FOX
# 2017  NALCS  Spring  Season         CLG        0        1         TL
#
#       gamelength   blueTop blueTopChamp  \
# Year
# 2017          41  Hauntzer       Maokai
# 2017          37    Impact     Nautilus
# 2017          39    Looper     Nautilus
# 2017          25       zig       Maokai
# 2017          35   Darshan     Nautilus
#
#                             ...                         redTopChamp  \
# Year                        ...
# 2017                        ...                                Shen
# 2017                        ...                             Trundle
# ...

# %%
# getting teams info for winning team to losing team and gamelength
df_bResult = df_year_1.set_index('bResult')
df_b_win = df_bResult.loc[1]
df_b_win_team = df_b_win[['blueTeamTag','redTeamTag','gamelength']]
df_b_win_team.head()
# Out:
#         blueTeamTag redTeamTag  gamelength
# bResult
# 1                C9        TSM          37
# 1                P1        FOX          25
# 1                TL        CLG          44
# 1               FLY         NV          37
# 1               FOX        IMT          49

# %%
df_b_win_team.to_csv("df_win_to_lose_1.csv")

# %%
df_b_win_team
# Out:
#         blueTeamTag redTeamTag  gamelength
# bResult
# 1                C9        TSM          37
# 1                P1        FOX          25
# 1                TL        CLG          44
# 1               FLY         NV          37
# 1               FOX        IMT          49
# 1               IMT        FOX          44
# 1               DIG         P1          39
# 1                P1        DIG          53
# 1               DIG         P1          37
# 1               TSM        IMT          53
# 1               IMT        TSM          51
# 1               TSM        IMT          39
# 1               CLG         NV          52
# 1                TL        FLY          45
# 1               FLY         TL          36
# 1               FLY        CLG          43
# 1               TSM        DIG          30
# 1                C9        IMT          40
# 1                P1         NV          42
# 1               TSM         TL          42
# 1                TL        TSM          43
# ...
